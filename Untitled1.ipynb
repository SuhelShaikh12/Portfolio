# %% [markdown]
# <a href="https://colab.research.google.com/github/SuhelShaikh12/Portfolio/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy pandas matplotlib scikit-learn tensorflow keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive
# Out:
#  15969842751787001789666792058223.jpg
#  1705432968707811.MP4
# '2026-Training Group- 5th Sem.xlsx'
# '26 GROUPS-2.xlsx'
# '2nd Year Detained List.xls'
# '48_Assessent 1 -CSAIIT- 27 Apr 2024_Attempted_27-04-2024.xlsx'
# '49_Assessent 1 -CSAIMLCSDSAIML- 27 Apr 2024_Attempted_27-04-2024.xlsx'
#  AdmitCard-220310418524.pdf
# 'Adobe Scan 13-Apr-2021.pdf'
#  BST-03_copy.pdf
#  C05074A6-B6F9-4864-BE44-468FDE0C5EFA.png
# 'Chemistry 3.xlsx'
# 'chem project SUH.gdoc'
#  Classroom
# 'Colab Notebooks'
#  dataset
#  DSA_Handwritten_Notes.PDF
#  EmergingDomaininElectronicsEngineering.gdoc
# 'first 4 pages[53] (1).gdoc'
# 'first 4 pages[53].gdoc'
#  Function.gdoc
# 'How to get started with Drive.pdf'
# 'https:  twitter.txt'
#  image.jpg
#  IMG-20150420-WA0026.jpg
#  IMG_20200522_201447.jpg
#  IMG_20200522_205828.jpg
#  IMG_7409.JPG
#  Lecture1.gdoc
#  Resume.gdoc
#  Safety_of_Women_Challenges_and_Measures.pdf
# 'SIH2024_IDEA_Presentation_Format[1] (1) (2).gslides'
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/dataset
# Out:
# train  val

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define directories
train_dir = '/content/drive/MyDrive/dataset/train'
val_dir = '/content/drive/MyDrive/dataset/val'

# Set up image data generators
train_datagen = ImageDataGenerator(rescale=1.0/255)  # Normalizing pixel values
val_datagen = ImageDataGenerator(rescale=1.0/255)

# Load training data in batches
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,  # Number of images loaded at once
    class_mode='binary'
)

# Load validation data in batches
val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 8873 images belonging to 2 classes.
# Found 600 images belonging to 2 classes.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Sigmoid for binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 32)        │               0 │
# ...

# %%
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator
)
# Out:
# Epoch 1/10
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 2770s 10s/step - accuracy: 0.6239 - loss: 0.6351 - val_accuracy: 0.6583 - val_loss: 0.6176
# Epoch 2/10
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 42s 148ms/step - accuracy: 0.8696 - loss: 0.3099 - val_accuracy: 0.6917 - val_loss: 0.6802
# Epoch 3/10
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 42s 147ms/step - accuracy: 0.9492 - loss: 0.1391 - val_accuracy: 0.7200 - val_loss: 0.8952
# Epoch 4/10
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 82s 147ms/step - accuracy: 0.9695 - loss: 0.0770 - val_accuracy: 0.6783 - val_loss: 1.2650
# Epoch 5/10
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 85s 156ms/step - accuracy: 0.9817 - loss: 0.0522 - val_accuracy: 0.6600 - val_loss: 1.2490
# Epoch 6/10
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 41s 144ms/step - accuracy: 0.9841 - loss: 0.0433 - val_accuracy: 0.6817 - val_loss: 1.3954
# Epoch 7/10
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 41s 146ms/step - accuracy: 0.9850 - loss: 0.0463 - val_accuracy: 0.6467 - val_loss: 1.4069
# Epoch 8/10
# ...

# %%
# Evaluate the model on the validation data
val_loss, val_accuracy = model.evaluate(val_generator)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.6833 - loss: 1.6398
# Validation Accuracy: 69.00%

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='best')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()

# %%
val_loss, val_accuracy = model.evaluate(val_generator)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")
print(f"Validation Loss: {val_loss:.4f}")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.6879 - loss: 1.5358
# Validation Accuracy: 69.00%
# Validation Loss: 1.5166

# %%
model.save('/content/drive/MyDrive/fracture_detection_model.keras')

# %%
# Save the model without the optimizer
model.save('/content/drive/MyDrive/fracture_detection_model.keras', include_optimizer=False)

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/drive/MyDrive/fracture_detection_model.keras')
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
print("File exists:", os.path.exists('/content/drive/MyDrive/notfractured.webp'))
# Out:
# File exists: True

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Correct path to your image
img_path = '/content/drive/MyDrive/broken.jpg'  # Update this path if your image is in a subfolder

# Load the image
img = cv2.imread(img_path)

# Check if the image was loaded
if img is None:
    print("Error: Image not found or unable to load. Please check the file path.")
else:
    print("Image loaded successfully with shape:", img.shape)
    # Convert BGR to RGB for displaying with matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.show()
# Out:
# Image loaded successfully with shape: (411, 612, 3)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('/content/drive/MyDrive/fracture_detection_model.keras')

# Path to your test image
img_path = '/content/drive/MyDrive/notfractured1.webp'    # Update this path if necessary

# Check if the file exists
if not os.path.exists(img_path):
    print("Error: Image file not found. Please check the path.")
else:
    # Load the image
    img = cv2.imread(img_path)

    # Verify that the image was loaded
    if img is None:
        print("Error: Unable to load the image. Please check the file format.")
    else:
        # Resize the image to the model's input size
        img = cv2.resize(img, (224, 224))  # Resize to match the model's input size
        img = img / 255.0  # Normalize pixel values to range [0, 1]
        img = np.expand_dims(img, axis=0)  # Add batch dimension

        # Make a prediction
        prediction = model.predict(img)

        # Interpret the prediction
        label = "Fractured" if prediction[0][0] > 0.3 else "Not Fractured"
        print(f"Prediction: {label}")

        # Display the image
        img_rgb = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
        plt.imshow(img_rgb)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# Prediction: Fractured

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define directories for training and validation datasets
train_dir = '/content/drive/MyDrive/dataset/train'
val_dir = '/content/drive/MyDrive/dataset/val'

# Data generators with augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# No augmentation for validation data; only rescaling
val_datagen = ImageDataGenerator(rescale=1.0/255)

# Create data generators
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'  # For binary classification
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 8873 images belonging to 2 classes.
# Found 600 images belonging to 2 classes.

# %%
import matplotlib.pyplot as plt

# Evaluate the model on the validation data
val_loss, val_accuracy = model.evaluate(val_generator)
print(f"Validation Loss: {val_loss}")
print(f"Validation Accuracy: {val_accuracy}")

# Plot training & validation accuracy and loss
history_dict = history.history
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']
epochs = range(1, len(acc) + 1)

# Plot accuracy
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 101s 5s/step - accuracy: 0.5954 - loss: 0.6805
# Validation Loss: 0.686404287815094
# Validation Accuracy: 0.5916666388511658
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e9d6111f6ab5> in <cell line: 9>()
#       7
#       8 # Plot training & validation accuracy and loss
# ----> 9 history_dict = history.history
#      10 acc = history_dict['accuracy']
#      11 val_acc = history_dict['val_accuracy']
#
# NameError: name 'history' is not defined

# %%
history = model.fit(train_generator, validation_data=val_generator, epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  18/278 ━━━━━━━━━━━━━━━━━━━━ 49:18 11s/step - accuracy: 0.5065 - loss: 1.8918
